# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot  as plt

# %%
df = pd.read_csv('AirPassengers.csv')
df
# Out:
#        Month  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# ..       ...         ...
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432
#
# [144 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df['Month'] = pd.to_datetime(df['Month'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    datetime64[ns]
#  1   Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
#line chart using seaborn

plt.figure(figsize = (10,5))
sns.lineplot(data = df,x = 'Month',y='Passengers')
plt.title('Monthly Air Passengers')
plt.xlabel('Month')
plt.ylabel('Passengers')
plt.show()

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#      age  sex     BP  cholestrol  heart disease
# 0     70    1  130.0       322.0            1.0
# 1     67    0  115.0       564.0            0.0
# 2     57    1  124.0       261.0            1.0
# 3     64    1  128.0       263.0            0.0
# 4     74    0  120.0       269.0            0.0
# ..   ...  ...    ...         ...            ...
# 265   52    1  172.0       199.0            0.0
# 266   44    1  120.0       263.0            0.0
# 267   56    0  140.0       294.0            0.0
# 268   57    1  140.0       192.0            0.0
# 269   67    1  160.0       286.0            1.0
#
# [270 rows x 5 columns]

# %%
plt.figure(figsize = (10,5))
sns.histplot(data = df , x='age')
plt.title('Age distribution')
plt.xlabel('age')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.histplot(data = df , x='age',bins = 5)
plt.title('Age distribution')
plt.xlabel('age')
plt.show()

# %%
df_male = df[df['sex'] == 1]
df_female = df[df['sex'] == 0]

# %%
plt.figure(figsize = (6,5))
sns.histplot(data = df_female , x='age',label = 'Female')
sns.histplot(data = df_male , x='age',label = 'Male')
plt.title('Age distribution')
plt.xlabel('age')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.histplot(data = df , x='age',hue = 'sex')
plt.title('Age distribution')
plt.xlabel('age')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.histplot(data = df , x='age',hue = 'sex')
plt.title('Age distribution')
plt.xlabel('age')
plt.ylabel('no of people')
plt.legend(title = 'sex' , labels = ['Male','Female'])
plt.show()

# %%
df = pd.read_csv('india_census_2011.csv')
df
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot  as plt

# %%
#histogram
df = pd.read_csv('churn_data.csv')
df
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0     7590-VHVEG       1           No  Month-to-month              Yes
# 1     5575-GNVDE      34          Yes        One year               No
# 2     3668-QPYBK       2          Yes  Month-to-month              Yes
# 3     7795-CFOCW      45           No        One year               No
# 4     9237-HQITU       2          Yes  Month-to-month              Yes
# ...          ...     ...          ...             ...              ...
# 7038  6840-RESVB      24          Yes        One year              Yes
# 7039  2234-XADUH      72          Yes        One year              Yes
# 7040  4801-JZAZL      11           No  Month-to-month              Yes
# 7041  8361-LTMKD       4          Yes  Month-to-month              Yes
# 7042  3186-AJIEK      66          Yes        Two year              Yes
#
#          PaymentMethod  MonthlyCharges  TotalCharges Churn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   PhoneService      7043 non-null   object
#  3   Contract          7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7034 non-null   float64
#  8   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 495.3+ KB

# %%
df.groupby('PaymentMethod')['MonthlyCharges'].agg(['mean','median'])
# Out:
#                        mean  median
# PaymentMethod
# Bank transfer     67.192649  73.100
# Credit card       66.512385  73.025
# Electronic check  76.255814  80.550
# Mailed check      43.917060  34.700

# %%
plt.figure(figsize = (6,5))
sns.barplot(data = df,x ='PaymentMethod',y='MonthlyCharges', errorbar = None)
plt.xlabel('PaymentMethod')
plt.ylabel('MonthlyCharges')
plt.title('Mean and median monthly payment distribution')
plt.xticks(rotation = 30)
plt.show()

# %%
df_readian_monthly_charges = df.groupby(['PaymentMethod'])['MonthlyCharges'].median().reset_index().sort_values(by = 'MonthlyCharges', ascending = False)
df_readian_monthly_charges
# Out:
#       PaymentMethod  MonthlyCharges
# 2  Electronic check          80.550
# 0     Bank transfer          73.100
# 1       Credit card          73.025
# 3      Mailed check          34.700

# %%
plt.figure(figsize = (6,5))
sns.barplot(data = df,x ='PaymentMethod',y='MonthlyCharges', errorbar = None,order = df_readian_monthly_charges['PaymentMethod'],estimator = 'median' )
plt.xlabel('PaymentMethod')
plt.ylabel('MonthlyCharges')
plt.title('Payment Method Distribution')
plt.xticks(rotation = 30)
plt.show()

# %%
plt.figure(figsize = (6,5))
sns.boxplot(data = df,y='MonthlyCharges')
plt.xlabel('MonthlyCharges')
plt.ylabel('box plot')
plt.show()

# %%
df = pd.read_csv('churn_data.csv')
df.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#       PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0  Electronic check           29.85         29.85    No
# 1      Mailed check           56.95       1889.50    No
# 2      Mailed check           53.85        108.15   Yes
# 3     Bank transfer           42.30       1840.75    No
# 4  Electronic check           70.70        151.65   Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   PhoneService      7043 non-null   object
#  3   Contract          7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7034 non-null   float64
#  8   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 495.3+ KB

# %%
df.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7034.000000
# mean     32.371149       64.761692   2282.792849
# std      24.559481       30.090047   2266.658844
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.350000
# 50%      29.000000       70.350000   1397.100000
# 75%      55.000000       89.850000   3793.775000
# max      72.000000      118.750000   8684.800000

# %%
plt.figure(figsize=(5,6))
sns.boxplot(data = df , y = 'MonthlyCharges')
plt.xlabel('MonthlyCharges')
plt.title('Box plot')
plt.show()

# %% [markdown]
# plt.figure(figsize = (6,7))
# sns.boxplot(data = df , x ='PaymentMethod',y ='MonthlyCharges',order = sorted(df['PaymentMethod'].unique()))
# plt.title('Box plot of monthly charges of each payment method')
# plt.xlabel('PaymentMethod')
# plt.xticks(rotation = 20)
# plt.show()

# %%
plt.figure(figsize = (5,3))
sns.boxplot(data = df, x = 'PaymentMethod', y = 'MonthlyCharges', order = sorted(df['PaymentMethod']))
plt.title('Box plot of monthly charges of each payment method')
plt.xlabel('Payment Method')
plt.xticks(rotation = 20)
plt.show()

# %%
plt.figure(figsize = (5,3))
sns.boxplot(data = df, x = 'PaymentMethod', y = 'MonthlyCharges', order = sorted(df['PaymentMethod']))
plt.title('Box plot of monthly charges of each payment method')
plt.xlabel('Payment Method')
plt.xticks(rotation = 20)
plt.show()

# %%
plt.figure(figsize = (5,3))
sns.boxplot(data = df, x = 'MonthlyCharges', y = 'PaymentMethod', order = sorted(df['PaymentMethod'].unique()))
plt.title('Box plot of monthly charges of each payment method')
plt.xlabel('Payment Method')
plt.xticks(rotation = 20)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('churn_data.csv')
df

"""Here are the counts of different payment method"""

df.info()

df.describe()

df.columns

payment_method_counts = df['PaymentMethod'].value_counts()
payment_method_counts

"""There is no pie chart method bulid in seaborn. Version = 0.13.2"""

plt.figure(figsize = (10,6))
plt.pie(x = payment_method_counts.values, labels = payment_method_counts.index, autopct= '%1.5f%%')
plt.title('Payment Method Distribution')
plt.show()
plt.pie

"""Add percentage"""

plt.figure(figsize = (10,6))
plt.pie(x = payment_method_counts.values, labels = payment_method_counts.index, autopct = '%.2f%%')
plt.title('Payment Method Distribution')
plt.show()

"""We could add annotations to show the percentage of each slice of the pie chart as well as explode a particular slice for emphasis:"""

plt.figure(figsize = (5, 3))
plt.pie(
    x = payment_method_counts.values,
    labels = payment_method_counts.index,
    autopct = '%.1f%%',
    explode = [0, 0, 0.1,0]
)
plt.title('Pie chart showing the distribution by payment method')
plt.show()

payment_method_counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   PhoneService      7043 non-null   object
#  3   Contract          7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7034 non-null   float64
#  8   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 495.3+ KB
# Electronic check    2365
# Mailed check        1612
# Bank transfer       1544
# Credit card         1522
# Name: PaymentMethod, dtype: int64

# %%
payment_method_counts = df['PaymentMethod'].value_counts()
payment_method_counts
# Out:
# Electronic check    2365
# Mailed check        1612
# Bank transfer       1544
# Credit card         1522
# Name: PaymentMethod, dtype: int64

# %%
plt.figure(figsize = (10,6))
plt.pie(x = payment_method_counts.values, labels = payment_method_counts.index, autopct= '%1.5f%%')
plt.title('Payment Method Distribution')
plt.show()
plt.pie
# Out:
# <function matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=True, hatch=None, data=None)>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   PhoneService      7043 non-null   object
#  3   Contract          7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7034 non-null   float64
#  8   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 495.3+ KB
